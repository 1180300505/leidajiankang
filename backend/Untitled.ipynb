# %%
import pandas as pd

# %%
df=pd.read_csv('data.csv', encoding='gbk')

# %%
df.columns
# Out:
# Index(['时间', '当前模式', '当前信号源', '信号源状态', '锁定状态', '锁定指示', 'AGC门限', 'AGC电压',
#        '方位误差电压', '俯仰误差电压', '转台系引导方位角', '转台系引导俯仰角', '转台系引导倾斜角', '转台系方位角',
#        '转台系俯仰角', '转台系倾斜角', '转台系方位偏差', '转台系俯仰偏差', '转台系倾斜偏差', '大地系引导方位角',
#        '大地系引导俯仰角', '大地系方位角', '大地系引导俯仰角.1', '大地系方位偏差', '大地系俯仰偏差', '方位轴电机1上电',
#        '方位轴电机2上电', '方位轴电机1状态', '方位轴电机2状态', '方位轴电机1电流', '方位轴电机2电流', '方位轴电机1电压',
#        '方位轴电机2电压', '方位轴电机1转动惯量', '方位轴电机2转动惯量', '方位轴电机1驱动器温度', '方位轴电机2驱动器温度',
#        'Unnamed: 37'],
#       dtype='object')

# %%
for name in df.columns:
    print(name, df[name].unique())
# Out:
# 时间 ['2025/12/30 15:16:35.700' '2025/12/30 15:16:35.800'
#  '2025/12/30 15:16:35.900' ... '2025/12/30 15:41:25.550'
#  '2025/12/30 15:41:25.600' '2025/12/30 15:41:25.700']
# 当前模式 ['指向' '待机']
# 当前信号源 [0]
# 信号源状态 ['未连接']
# 锁定状态 ['未锁定']
# 锁定指示 ['未锁定']
# AGC门限 [2.5]
# AGC电压 [0.]
# 方位误差电压 [5.]
# 俯仰误差电压 [5.]
# 转台系引导方位角 [219.397 219.416 219.4   219.41  219.42  219.43  219.44  219.45  219.46
#  219.399 219.349 219.449 219.459 219.439 219.429 219.419 219.409]
# 转台系引导俯仰角 [16.094 16.021 15.966 16.113 16.163 16.063 16.133 16.153 16.143 16.123]
# 转台系引导倾斜角 [0.994]
# 转台系方位角 [219.416 219.425 219.433 219.435 219.434 219.436 219.432 219.429 219.424
#  219.418 219.411 219.407 219.405 219.402 219.401 219.4   219.397 219.394
#  219.393 219.395 219.396 219.398 219.399 219.412 219.413 219.41  219.409
#  219.406 219.404 219.403 219.408 219.417 219.414 219.392 219.391 219.39
#  219.389 219.421 219.422 219.42  219.419 219.415 219.431 219.43  219.428
# ...
